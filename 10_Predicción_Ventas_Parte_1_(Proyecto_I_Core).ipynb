# %% [markdown]
# #Análisis y Predicción de Ventas en una Tienda de Retail (Core)

# %% [markdown]
# **1-Configuración Inicial del Proyecto:**
# * Crea un repositorio en GitHub para tu proyecto.
# * Configura dos ramas en tu repositorio: main y development.
# * Agrega un archivo README.md con una descripción del proyecto, instrucciones de instalación y uso.

# %%
"""
1- Configuración Inicial del Proyecto en GitHub
* Crear un Repositorio en GitHub:
* Ve a GitHub y crea un nuevo repositorio.
* Nombra el repositorio, por ejemplo, retail-sales-analysis

2- Clonar el Repositorio a tu Máquina Local:
* Abre tu terminal y clona el repositorio:
git clone https://github.com/Miguel-Sanabria/retail_sales_analysis.git
cd retail-sales-analysis

3- Crear Ramas main y development:
* Asegúrate de estar en la rama main:
git checkout main

* Crea y cambia a la rama development:
git checkout -b development

4- Agregar un Archivo README.md
* Crea un archivo README.md con la siguiente estructura:
# Retail Sales Analysis

Este proyecto analiza y predice las ventas de una tienda de retail utilizando técnicas de ciencia de datos.

## Estructura del Proyecto

- `data/`: Contiene los archivos de datos.
- `notebooks/`: Contiene los notebooks de Jupyter para el análisis.
- `src/`: Contiene el código fuente del proyecto.
- `README.md`: Este archivo.

## Instrucciones de Instalación

1. Clona el repositorio: `git clone https://github.com/Miguel-Sanabria/retail_sales_analysis.git`
2. Instala las dependencias: `pip install -r requirements.txt`

## Uso

Ejecuta los notebooks de Jupyter en la carpeta `notebooks` para realizar el análisis de los datos.

5- Hacer un Commit y Push de los Cambios:
* Agrega y comitea los cambios:
git add README.md
git commit -m "Add README.md"
"""
# Out:
# '\n1- Configuración Inicial del Proyecto en GitHub\n* Crear un Repositorio en GitHub:\n* Ve a GitHub y crea un nuevo repositorio.\n* Nombra el repositorio, por ejemplo, retail-sales-analysis\n\n2- Clonar el Repositorio a tu Máquina Local:\n* Abre tu terminal y clona el repositorio:\ngit clone https://github.com/Miguel-Sanabria/retail_sales_analysis.git\ncd retail-sales-analysis\n\n3- Crear Ramas main y development:\n* Asegúrate de estar en la rama main:\ngit checkout main\n\n* Crea y cambia a la rama development:\ngit checkout -b development\n\n4- Agregar un Archivo README.md\n* Crea un archivo README.md con la siguiente estructura:\n# Retail Sales Analysis\n\nEste proyecto analiza y predice las ventas de una tienda de retail utilizando técnicas de ciencia de datos.\n\n## Estructura del Proyecto\n\n- `data/`: Contiene los archivos de datos.\n- `notebooks/`: Contiene los notebooks de Jupyter para el análisis.\n- `src/`: Contiene el código fuente del proyecto.\n- `README.md`: Este archivo.\n\n## Instrucciones de Instalación\n\n1. Clona el repositorio: `git clone https://github.com/Miguel-Sanabria/retail_sales_analysis.git`\n2. Instala las dependencias: `pip install -r requirements.txt`\n\n## Uso\n\nEjecuta los notebooks de Jupyter en la carpeta `notebooks` para realizar el análisis de los datos.\n\n5- Hacer un Commit y Push de los Cambios:\n* Agrega y comitea los cambios:\ngit add README.md\ngit commit -m "Add README.md"\n'

# %% [markdown]
# **2- Carga y Preprocesamiento de Datos:**
# * Carga los datos del archivo CSV utilizando NumPy.
# * Realiza un preprocesamiento básico para asegurarte de que los datos estén limpios y listos para su análisis.
#
# **3- Exploración de Datos:**
# * Calcula el total de ventas por producto y por tienda.
# * Calcula el promedio de ventas diarias por producto y por tienda.
# * Identifica los productos y tiendas con mayores y menores ventas.
#
# **4- Manipulación de Datos:**
# * Filtra los datos para mostrar solo las ventas de un producto específico.
# * Filtra los datos para mostrar solo las ventas de una tienda específica.
# * Realiza operaciones de suma, resta, multiplicación y división en los datos para obtener estadísticas adicionales.

# %%
def cargar_datos(ruta_archivo):
    # Carga los datos del archivo CSV utilizando NumPy
    data = np.genfromtxt(ruta_archivo, delimiter=',', skip_header=1)
    return data

def ventas_por_productos_tiendas(data):
    # Extraer las columnas necesarias
    productos = data[:, 1]  # Columna de productos
    tiendas = data[:,3]  # Columna de tiendas
    ventas = data[:,4]  # Columna de ventas

    # Obtener productos y tiendas únicos
    productos_unicos, idx_productos = np.unique(productos, return_inverse=True)
    tiendas_unicas, idx_tiendas = np.unique(tiendas, return_inverse=True)

    # Crear una matriz para almacenar las sumas de ingresos por producto y tienda
    total_ventas = np.zeros((len(productos_unicos), len(tiendas_unicas)))

    # Sumar los ingresos por producto y tienda
    for i in range(len(ventas)):
        total_ventas[idx_productos[i], idx_tiendas[i]] += ventas[i]

    return productos_unicos, tiendas_unicas, total_ventas

def promedio_ventas_por_productos_tiendas(data):
    # Extraer las columnas necesarias
    productos = data[:, 1]  # Columna de productos
    tiendas = data[:,3]  # Columna de tiendas
    ventas = data[:,4]  # Columna de ventas
    fechas = data[:,0]  # Columna de fechas

    # Obtener productos y tiendas únicos
    productos_unicos, idx_productos = np.unique(productos, return_inverse=True)
    tiendas_unicas, idx_tiendas = np.unique(tiendas, return_inverse=True)

    # Crear una matriz para almacenar las ventas por día y tienda
    suma_ventas = np.zeros((len(productos_unicos), len(tiendas_unicas)))
    conteo_dias = np.zeros((len(productos_unicos), len(tiendas_unicas)))

    # Usamos un array de tipo object para almacenar fechas
    fechas_unicas = np.empty_like(suma_ventas, dtype=object)  # Cambiaamos a dtype=object porque no acepta string

    # Sumar ventas y contar días únicos
    for i in range(len(ventas)):
        prod_idx = idx_productos[i]
        tienda_idx = idx_tiendas[i]

        # Evitar contar la misma fecha más de una vez
        fecha_actual = fechas[i]
        if fechas_unicas[prod_idx, tienda_idx] != fecha_actual:
            conteo_dias[prod_idx, tienda_idx] += 1
            fechas_unicas[prod_idx, tienda_idx] = fecha_actual

        suma_ventas[prod_idx, tienda_idx] += ventas[i]

    # Calcular el promedio dividiendo el total de ventas entre los días
    promedio_ventas = np.divide(suma_ventas, conteo_dias, out=np.zeros_like(suma_ventas), where=conteo_dias!=0)

    return productos_unicos, tiendas_unicas, promedio_ventas

def productos_mayores_menores_ventas(productos_unicos, tiendas_unicas, total_ventas):
    # Encontrar la venta máxima y mínima
    max_ventas = np.max(total_ventas)
    min_ventas = np.min(total_ventas)

    # Encontrar los índices de los valores máximos y mínimos
    max_indices = np.where(total_ventas == max_ventas)
    min_indices = np.where(total_ventas == min_ventas)

    # Obtener los productos y tiendas correspondientes
    productos_max = productos_unicos[max_indices[0]]
    tiendas_max = tiendas_unicas[max_indices[1]]

    productos_min = productos_unicos[min_indices[0]]
    tiendas_min = tiendas_unicas[min_indices[1]]

    return (productos_max, tiendas_max, max_ventas), (productos_min, tiendas_min, min_ventas)

def filtrar_por_producto(data, producto_especifico):
    # Filtrar los datos para obtener solo las filas que corresponden al producto específico
    filtro_producto = data[:, 1] == producto_especifico

    # Extraer las ventas y otras columnas correspondientes al producto específico
    ventas_producto_especifico = data[:,4][filtro_producto]
    tiendas_producto_especifico = data[:, 3][filtro_producto]

    # Crear listas para almacenar los resultados
    tiendas_resultados = []
    ventas_resultados = []

    # Llenar las listas con los datos filtrados
    for i in range(len(ventas_producto_especifico)):
        tiendas_resultados.append(tiendas_producto_especifico[i])
        ventas_resultados.append(ventas_producto_especifico[i])

    # Convertir las listas a una matriz de NumPy
    resultados = np.array(list(zip(tiendas_resultados, ventas_resultados)),
        dtype=object)

    return resultados

def filtrar_por_tienda(data, tienda_especifico):
    # Filtrar los datos para obtener solo las filas que corresponden al producto específico
    filtro_tienda = data[:, 3] == tienda_especifico

    # Extraer las ventas y otras columnas correspondientes al producto específico
    ventas_tienda_especifico = data[:,4][filtro_tienda]
    producto_tienda_especifico = data[:, 1][filtro_tienda]

    # Crear listas para almacenar los resultados
    productos_resultados = []
    ventas_resultados = []

    # Llenar las listas con los datos filtrados
    for i in range(len(ventas_tienda_especifico)):
        productos_resultados.append(producto_tienda_especifico[i])
        ventas_resultados.append(ventas_tienda_especifico[i])

    # Convertir las listas a una matriz de NumPy
    resultados = np.array(list(zip(productos_resultados, ventas_resultados)),
        dtype=object)

    return resultados

def describe(data):
    # Extraer la columna de ventas
    ventas = data[:, 4]  # Columna de ventas
    # Calcular estadísticas adicionales
    total_ventas = np.sum(ventas)           # Suma total de ventas
    promedio_ventas = np.mean(ventas)       # Promedio de ventas
    ventas_max = np.max(ventas)             # Venta máxima
    ventas_min = np.min(ventas)             # Venta mínima
    desviacion_estandar = np.std(ventas)    #desviación estándar de las ventas
    return total_ventas, promedio_ventas, ventas_max, ventas_min, desviacion_estandar

if __name__ == "__main__":

    # Carga los datos del archivo CSV utilizando NumPy.
    import numpy as np
    # Ruta del archivo CSV
    ruta_archivo = '/content/Datos_tienda.csv'
    data = cargar_datos(ruta_archivo)
    print(f"\nDatos del archivo\n{data}")

    # Calcula el total de ventas por producto y por tienda.
    productos, tiendas, total_ventas = ventas_por_productos_tiendas(data)
    print(f"\nTotal de ventas por producto y por tienda\n{total_ventas}")

    # Calcula el promedio de ventas diarias por producto y por tienda.
    productos, tiendas, promedio_ventas = promedio_ventas_por_productos_tiendas(data)
    print(f"\nPromedio de ventas diarias por producto y por tienda\n{promedio_ventas}")

    # Identifica los productos y tiendas con mayores y menores ventas
    (productos_max, tiendas_max, max_ventas), (productos_min, tiendas_min, min_ventas) = productos_mayores_menores_ventas(productos, tiendas, total_ventas)
    print(f"\nMayor venta: Producto(s) {productos_max} en Tienda(s) {tiendas_max} con {max_ventas}")
    print(f"Menor venta: Producto(s) {productos_min} en Tienda(s) {tiendas_min} con {min_ventas}")

    # Filtrar por un producto específico y obtener la matriz
    producto_especifico = 31
    matriz_resultados = filtrar_por_producto(data, producto_especifico)

    # Mostrar los resultados
    print(f"\nVentas del producto {producto_especifico}:")
    for row in matriz_resultados:
        print(f"Tienda: {row[0]}, Venta: {row[1]}")

    # Filtrar por una tienda específica y obtener la matriz
    tienda_especifico = 3
    matriz_resultados = filtrar_por_tienda(data, tienda_especifico)

    # Mostrar los resultados
    print(f"\nVentas por tienda {tienda_especifico}:")
    for row in matriz_resultados:
        print(f"Producto: {row[0]}, Venta: {row[1]}")

    # Calcular estadísticas adicionales
    (total_ventas, promedio_ventas, ventas_max, ventas_min, desviacion_estandar) = describe(data)
    print(f"\nTotal de ventas: {total_ventas}")
    print(f"Promedio de ventas: {promedio_ventas:.2f}")
    print(f"Venta máxima: {ventas_max}")
    print(f"Venta mínima: {ventas_min}")
    print(f"Desviación estándar de las ventas: {desviacion_estandar:.2f}")
# Out:
# Datos del archivo
# [[      nan 1.900e+01 8.936e+03 1.000e+00 6.000e+00]
#  [      nan 4.300e+01 8.765e+03 1.000e+00 4.600e+01]
#  [      nan 3.000e+01 8.235e+03 1.000e+00 7.600e+01]
#  ...
#  [      nan 4.200e+01 5.384e+03 5.000e+00 8.700e+01]
#  [      nan 2.400e+01 9.925e+03 5.000e+00 5.500e+01]
#  [      nan 2.400e+01 7.461e+03 5.000e+00 3.600e+01]]
#
# Total de ventas por producto y por tienda
# [[1451. 1664. 1376. 1299. 1636.]
#  [1463. 1683. 1400. 1309. 1480.]
#  [1506. 1493. 1898. 1875. 1690.]
#  [1028. 1132. 1567. 2101. 2023.]
#  [1322. 1432. 1545. 1842. 1875.]
#  [1472. 1915. 1568. 1179. 1705.]
#  [1284. 1727. 1420. 1706. 1715.]
#  [ 880. 1723. 1684. 1652.  855.]
#  [1616. 1322. 1827.  894. 1751.]
#  [1896. 1515. 2100. 1581. 1896.]
#  [1979. 1804. 1574. 1311. 1762.]
#  [1129. 1333. 1327. 1761. 1514.]
#  [1620. 1862. 1298. 2118. 1655.]
#  [2066. 2045. 1942. 1156. 1545.]
#  [2030. 1890. 1680. 1345. 1424.]
#  [1606.  924. 1101. 1238. 1065.]
#  [1192. 1856. 1801. 1831. 1426.]
#  [1524. 1863. 1614. 1662. 1344.]
#  [2460. 1335. 1223. 1173. 1479.]
#  [1243. 1375. 1375. 1422. 1504.]
#  [1146. 1760. 1660. 1414. 1234.]
#  [1644. 1995. 1448. 1593. 2074.]
#  [1760.  577. 1889. 1460. 1417.]
#  [1317. 1710. 1210. 1129. 1797.]
#  [2072. 2081. 1692. 1731. 1587.]
#  [1488. 1492. 1370. 1830. 1392.]
#  [1771. 2124. 1447. 2013. 1465.]
#  [1689. 1784. 1321. 1317. 1393.]
#  [1337. 1676. 1650. 1556. 1445.]
#  [1741.  835. 1629. 1692. 1225.]
#  [1589. 1406. 1837. 1294. 1596.]
#  [1664. 1407. 1061. 1860. 1662.]
#  [1634. 1966. 1755. 1900. 1249.]
#  [1231. 1698. 1895. 1495. 1103.]
#  [1147.  968.  928. 1658.  854.]
#  [1579. 1436. 1648. 1062. 1543.]]
#
# Promedio de ventas diarias por producto y por tienda
# [[60.45833333 48.94117647 52.92307692 51.96       49.57575758]
#  [48.76666667 52.59375    50.         54.54166667 47.74193548]
#  [55.77777778 49.76666667 48.66666667 50.67567568 54.51612903]
#  [51.4        56.6        54.03448276 56.78378378 50.575     ]
#  [55.08333333 53.03703704 48.28125    55.81818182 48.07692308]
#  [47.48387097 58.03030303 47.51515152 45.34615385 55.        ]
#  [51.36       59.55172414 44.375      47.38888889 49.        ]
#  [48.88888889 52.21212121 67.36       55.06666667 50.29411765]
#  [48.96969697 45.5862069  50.75       40.63636364 54.71875   ]
#  [49.89473684 58.26923077 58.33333333 52.7        44.09302326]
#  [48.26829268 58.19354839 50.77419355 48.55555556 55.0625    ]
#  [43.42307692 55.54166667 53.08       58.7        50.46666667]
#  [52.25806452 54.76470588 48.07407407 50.42857143 53.38709677]
#  [54.36842105 55.27027027 52.48648649 48.16666667 55.17857143]
#  [54.86486486 54.         49.41176471 49.81481481 43.15151515]
#  [51.80645161 46.2        39.32142857 51.58333333 48.40909091]
#  [42.57142857 53.02857143 56.28125    53.85294118 50.92857143]
#  [46.18181818 50.35135135 47.47058824 59.35714286 53.76      ]
#  [57.20930233 44.5        50.95833333 43.44444444 42.25714286]
#  [54.04347826 52.88461538 55.         45.87096774 41.77777778]
#  [45.84       51.76470588 46.11111111 42.84848485 51.41666667]
#  [49.81818182 49.875      51.71428571 54.93103448 51.85      ]
#  [51.76470588 36.0625     51.05405405 44.24242424 59.04166667]
#  [48.77777778 50.29411765 48.4        37.63333333 57.96774194]
#  [54.52631579 56.24324324 51.27272727 49.45714286 48.09090909]
#  [46.5        51.44827586 41.51515152 48.15789474 48.        ]
#  [44.275      55.89473684 55.65384615 52.97368421 45.78125   ]
#  [56.3        66.07407407 57.43478261 43.9        51.59259259]
#  [46.10344828 42.97435897 51.5625     53.65517241 57.8       ]
#  [54.40625    39.76190476 50.90625    49.76470588 45.37037037]
#  [45.4        42.60606061 59.25806452 44.62068966 45.6       ]
#  [53.67741935 46.9        44.20833333 58.125      44.91891892]
#  [58.35714286 51.73684211 48.75       55.88235294 52.04166667]
#  [43.96428571 56.6        55.73529412 51.55172414 42.42307692]
#  [52.13636364 50.94736842 42.18181818 57.17241379 42.7       ]
#  [50.93548387 49.51724138 53.16129032 53.1        51.43333333]]
#
# Mayor venta: Producto(s) [33.] en Tienda(s) [1.] con 2460.0
# Menor venta: Producto(s) [37.] en Tienda(s) [2.] con 577.0
#
# Ventas del producto 31:
# Tienda: 1.0, Venta: 55.0
# Tienda: 1.0, Venta: 35.0
# Tienda: 1.0, Venta: 19.0
# Tienda: 1.0, Venta: 1.0
# Tienda: 1.0, Venta: 0.0
# Tienda: 1.0, Venta: 20.0
# Tienda: 1.0, Venta: 24.0
# Tienda: 1.0, Venta: 54.0
# Tienda: 1.0, Venta: 7.0
# Tienda: 1.0, Venta: 62.0
# Tienda: 1.0, Venta: 20.0
# Tienda: 1.0, Venta: 48.0
# Tienda: 1.0, Venta: 10.0
# Tienda: 1.0, Venta: 98.0
# Tienda: 1.0, Venta: 90.0
# Tienda: 1.0, Venta: 41.0
# Tienda: 1.0, Venta: 17.0
# Tienda: 1.0, Venta: 59.0
# Tienda: 1.0, Venta: 25.0
# Tienda: 1.0, Venta: 70.0
# Tienda: 1.0, Venta: 19.0
# Tienda: 1.0, Venta: 78.0
# Tienda: 1.0, Venta: 88.0
# Tienda: 1.0, Venta: 80.0
# Tienda: 1.0, Venta: 70.0
# Tienda: 1.0, Venta: 36.0
# Tienda: 1.0, Venta: 23.0
# Tienda: 1.0, Venta: 43.0
# Tienda: 2.0, Venta: 98.0
# Tienda: 2.0, Venta: 7.0
# Tienda: 2.0, Venta: 16.0
# Tienda: 2.0, Venta: 73.0
# Tienda: 2.0, Venta: 17.0
# Tienda: 2.0, Venta: 21.0
# Tienda: 2.0, Venta: 83.0
# Tienda: 2.0, Venta: 29.0
# Tienda: 2.0, Venta: 69.0
# Tienda: 2.0, Venta: 99.0
# Tienda: 2.0, Venta: 85.0
# Tienda: 2.0, Venta: 88.0
# Tienda: 2.0, Venta: 21.0
# Tienda: 2.0, Venta: 76.0
# Tienda: 2.0, Venta: 75.0
# Tienda: 2.0, Venta: 19.0
# Tienda: 2.0, Venta: 38.0
# Tienda: 2.0, Venta: 84.0
# Tienda: 2.0, Venta: 38.0
# Tienda: 2.0, Venta: 19.0
# Tienda: 2.0, Venta: 43.0
# Tienda: 2.0, Venta: 98.0
# Tienda: 2.0, Venta: 23.0
# Tienda: 2.0, Venta: 94.0
# Tienda: 2.0, Venta: 15.0
# Tienda: 2.0, Venta: 38.0
# Tienda: 2.0, Venta: 18.0
# Tienda: 2.0, Venta: 74.0
# Tienda: 2.0, Venta: 86.0
# Tienda: 2.0, Venta: 36.0
# Tienda: 2.0, Venta: 34.0
# Tienda: 2.0, Venta: 58.0
# Tienda: 2.0, Venta: 96.0
# Tienda: 2.0, Venta: 6.0
# Tienda: 2.0, Venta: 82.0
# Tienda: 3.0, Venta: 42.0
# Tienda: 3.0, Venta: 60.0
# Tienda: 3.0, Venta: 27.0
# Tienda: 3.0, Venta: 100.0
# Tienda: 3.0, Venta: 14.0
# Tienda: 3.0, Venta: 91.0
# Tienda: 3.0, Venta: 13.0
# Tienda: 3.0, Venta: 79.0
# Tienda: 3.0, Venta: 67.0
# Tienda: 3.0, Venta: 83.0
# Tienda: 3.0, Venta: 51.0
# Tienda: 3.0, Venta: 31.0
# Tienda: 3.0, Venta: 77.0
# Tienda: 3.0, Venta: 15.0
# Tienda: 3.0, Venta: 38.0
# Tienda: 3.0, Venta: 95.0
# Tienda: 3.0, Venta: 48.0
# Tienda: 3.0, Venta: 100.0
# Tienda: 3.0, Venta: 87.0
# Tienda: 3.0, Venta: 57.0
# Tienda: 3.0, Venta: 71.0
# Tienda: 3.0, Venta: 65.0
# Tienda: 3.0, Venta: 66.0
# Tienda: 3.0, Venta: 97.0
# Tienda: 3.0, Venta: 83.0
# Tienda: 3.0, Venta: 17.0
# Tienda: 3.0, Venta: 70.0
# Tienda: 3.0, Venta: 46.0
# Tienda: 3.0, Venta: 28.0
# Tienda: 3.0, Venta: 36.0
# Tienda: 3.0, Venta: 23.0
# Tienda: 3.0, Venta: 24.0
# Tienda: 4.0, Venta: 5.0
# Tienda: 4.0, Venta: 70.0
# Tienda: 4.0, Venta: 92.0
# Tienda: 4.0, Venta: 89.0
# Tienda: 4.0, Venta: 45.0
# Tienda: 4.0, Venta: 52.0
# Tienda: 4.0, Venta: 96.0
# Tienda: 4.0, Venta: 84.0
# Tienda: 4.0, Venta: 0.0
# Tienda: 4.0, Venta: 58.0
# Tienda: 4.0, Venta: 98.0
# Tienda: 4.0, Venta: 98.0
# Tienda: 4.0, Venta: 35.0
# Tienda: 4.0, Venta: 11.0
# Tienda: 4.0, Venta: 48.0
# Tienda: 4.0, Venta: 86.0
# Tienda: 4.0, Venta: 55.0
# Tienda: 4.0, Venta: 41.0
# Tienda: 4.0, Venta: 10.0
# Tienda: 4.0, Venta: 54.0
# Tienda: 4.0, Venta: 43.0
# Tienda: 4.0, Venta: 80.0
# Tienda: 4.0, Venta: 3.0
# Tienda: 4.0, Venta: 83.0
# Tienda: 4.0, Venta: 86.0
# Tienda: 4.0, Venta: 9.0
# Tienda: 4.0, Venta: 39.0
# Tienda: 4.0, Venta: 99.0
# Tienda: 4.0, Venta: 46.0
# Tienda: 4.0, Venta: 94.0
# Tienda: 4.0, Venta: 53.0
# Tienda: 4.0, Venta: 57.0
# Tienda: 4.0, Venta: 6.0
# Tienda: 4.0, Venta: 6.0
# Tienda: 5.0, Venta: 27.0
# Tienda: 5.0, Venta: 58.0
# Tienda: 5.0, Venta: 66.0
# Tienda: 5.0, Venta: 64.0
# Tienda: 5.0, Venta: 25.0
# Tienda: 5.0, Venta: 29.0
# Tienda: 5.0, Venta: 40.0
# Tienda: 5.0, Venta: 35.0
# Tienda: 5.0, Venta: 87.0
# Tienda: 5.0, Venta: 56.0
# Tienda: 5.0, Venta: 92.0
# Tienda: 5.0, Venta: 97.0
# Tienda: 5.0, Venta: 96.0
# Tienda: 5.0, Venta: 0.0
# Tienda: 5.0, Venta: 79.0
# Tienda: 5.0, Venta: 72.0
# Tienda: 5.0, Venta: 23.0
# Tienda: 5.0, Venta: 49.0
# Tienda: 5.0, Venta: 65.0
# Tienda: 5.0, Venta: 2.0
# Tienda: 5.0, Venta: 98.0
# Tienda: 5.0, Venta: 1.0
# Tienda: 5.0, Venta: 20.0
# Tienda: 5.0, Venta: 68.0
# Tienda: 5.0, Venta: 96.0
# Tienda: 5.0, Venta: 15.0
# Tienda: 5.0, Venta: 35.0
# Tienda: 5.0, Venta: 31.0
#
# Ventas por tienda 3:
# Producto: 47.0, Venta: 22.0
# Producto: 28.0, Venta: 53.0
# Producto: 24.0, Venta: 59.0
# Producto: 19.0, Venta: 15.0
# Producto: 25.0, Venta: 10.0
# Producto: 34.0, Venta: 44.0
# Producto: 43.0, Venta: 92.0
# Producto: 32.0, Venta: 66.0
# Producto: 23.0, Venta: 28.0
# Producto: 24.0, Venta: 82.0
# Producto: 18.0, Venta: 19.0
# Producto: 28.0, Venta: 53.0
# Producto: 23.0, Venta: 97.0
# Producto: 22.0, Venta: 31.0
# Producto: 27.0, Venta: 31.0
# Producto: 47.0, Venta: 55.0
# Producto: 25.0, Venta: 85.0
# Producto: 47.0, Venta: 63.0
# Producto: 29.0, Venta: 76.0
# Producto: 43.0, Venta: 8.0
# Producto: 47.0, Venta: 93.0
# Producto: 35.0, Venta: 36.0
# Producto: 45.0, Venta: 46.0
# Producto: 24.0, Venta: 93.0
# Producto: 17.0, Venta: 73.0
# Producto: 27.0, Venta: 53.0
# Producto: 35.0, Venta: 92.0
# Producto: 29.0, Venta: 57.0
# Producto: 29.0, Venta: 6.0
# Producto: 48.0, Venta: 90.0
# Producto: 29.0, Venta: 95.0
# Producto: 32.0, Venta: 57.0
# Producto: 33.0, Venta: 22.0
# Producto: 41.0, Venta: 58.0
# Producto: 40.0, Venta: 4.0
# Producto: 27.0, Venta: 92.0
# Producto: 43.0, Venta: 25.0
# Producto: 31.0, Venta: 42.0
# Producto: 37.0, Venta: 70.0
# Producto: 21.0, Venta: 83.0
# Producto: 19.0, Venta: 9.0
# Producto: 26.0, Venta: 17.0
# Producto: 22.0, Venta: 94.0
# Producto: 39.0, Venta: 31.0
# Producto: 29.0, Venta: 5.0
# Producto: 34.0, Venta: 56.0
# Producto: 31.0, Venta: 60.0
# Producto: 22.0, Venta: 15.0
# Producto: 19.0, Venta: 50.0
# Producto: 50.0, Venta: 86.0
# Producto: 40.0, Venta: 21.0
# Producto: 44.0, Venta: 74.0
# Producto: 44.0, Venta: 32.0
# Producto: 37.0, Venta: 9.0
# Producto: 34.0, Venta: 52.0
# Producto: 39.0, Venta: 92.0
# Producto: 26.0, Venta: 6.0
# Producto: 24.0, Venta: 35.0
# Producto: 43.0, Venta: 6.0
# Producto: 30.0, Venta: 82.0
# Producto: 16.0, Venta: 12.0
# Producto: 48.0, Venta: 52.0
# Producto: 45.0, Venta: 24.0
# Producto: 39.0, Venta: 57.0
# Producto: 26.0, Venta: 50.0
# Producto: 15.0, Venta: 97.0
# Producto: 40.0, Venta: 17.0
# Producto: 17.0, Venta: 53.0
# Producto: 48.0, Venta: 75.0
# Producto: 24.0, Venta: 43.0
# Producto: 15.0, Venta: 19.0
# Producto: 32.0, Venta: 96.0
# Producto: 49.0, Venta: 70.0
# Producto: 38.0, Venta: 80.0
# Producto: 43.0, Venta: 96.0
# Producto: 26.0, Venta: 59.0
# Producto: 45.0, Venta: 65.0
# Producto: 28.0, Venta: 37.0
# Producto: 32.0, Venta: 10.0
# Producto: 27.0, Venta: 82.0
# Producto: 23.0, Venta: 12.0
# Producto: 21.0, Venta: 31.0
# Producto: 28.0, Venta: 76.0
# Producto: 19.0, Venta: 71.0
# Producto: 25.0, Venta: 32.0
# Producto: 43.0, Venta: 99.0
# Producto: 41.0, Venta: 77.0
# Producto: 35.0, Venta: 28.0
# Producto: 27.0, Venta: 68.0
# Producto: 24.0, Venta: 96.0
# Producto: 45.0, Venta: 53.0
# Producto: 35.0, Venta: 56.0
# Producto: 35.0, Venta: 54.0
# Producto: 20.0, Venta: 18.0
# Producto: 40.0, Venta: 38.0
# Producto: 29.0, Venta: 81.0
# Producto: 44.0, Venta: 40.0
# Producto: 44.0, Venta: 43.0
# Producto: 48.0, Venta: 72.0
# Producto: 27.0, Venta: 24.0
# Producto: 23.0, Venta: 99.0
# Producto: 38.0, Venta: 93.0
# Producto: 48.0, Venta: 14.0
# Producto: 42.0, Venta: 47.0
# Producto: 47.0, Venta: 84.0
# Producto: 47.0, Venta: 12.0
# Producto: 32.0, Venta: 45.0
# Producto: 30.0, Venta: 0.0
# Producto: 38.0, Venta: 43.0
# Producto: 26.0, Venta: 15.0
# Producto: 49.0, Venta: 8.0
# Producto: 39.0, Venta: 0.0
# Producto: 17.0, Venta: 4.0
# Producto: 48.0, Venta: 83.0
# Producto: 34.0, Venta: 77.0
# Producto: 31.0, Venta: 27.0
# Producto: 20.0, Venta: 55.0
# Producto: 43.0, Venta: 57.0
# Producto: 15.0, Venta: 35.0
# Producto: 29.0, Venta: 81.0
# Producto: 24.0, Venta: 59.0
# Producto: 17.0, Venta: 100.0
# Producto: 46.0, Venta: 17.0
# Producto: 28.0, Venta: 62.0
# Producto: 19.0, Venta: 60.0
# Producto: 30.0, Venta: 41.0
# Producto: 15.0, Venta: 88.0
# Producto: 50.0, Venta: 77.0
# Producto: 30.0, Venta: 24.0
# Producto: 50.0, Venta: 91.0
# Producto: 21.0, Venta: 36.0
# Producto: 25.0, Venta: 14.0
# Producto: 24.0, Venta: 10.0
# Producto: 41.0, Venta: 64.0
# Producto: 28.0, Venta: 18.0
# Producto: 35.0, Venta: 23.0
# Producto: 36.0, Venta: 38.0
# Producto: 41.0, Venta: 59.0
# Producto: 16.0, Venta: 66.0
# Producto: 21.0, Venta: 92.0
# Producto: 33.0, Venta: 22.0
# Producto: 15.0, Venta: 80.0
# Producto: 48.0, Venta: 68.0
# Producto: 38.0, Venta: 38.0
# Producto: 37.0, Venta: 59.0
# Producto: 29.0, Venta: 50.0
# Producto: 27.0, Venta: 44.0
# Producto: 16.0, Venta: 49.0
# Producto: 35.0, Venta: 0.0
# Producto: 15.0, Venta: 3.0
# Producto: 30.0, Venta: 0.0
# Producto: 32.0, Venta: 50.0
# Producto: 17.0, Venta: 30.0
# Producto: 44.0, Venta: 14.0
# Producto: 20.0, Venta: 8.0
# Producto: 39.0, Venta: 45.0
# Producto: 37.0, Venta: 86.0
# Producto: 31.0, Venta: 100.0
# Producto: 48.0, Venta: 32.0
# Producto: 34.0, Venta: 91.0
# Producto: 44.0, Venta: 91.0
# Producto: 15.0, Venta: 83.0
# Producto: 36.0, Venta: 39.0
# Producto: 17.0, Venta: 1.0
# Producto: 29.0, Venta: 10.0
# Producto: 21.0, Venta: 58.0
# Producto: 47.0, Venta: 34.0
# Producto: 39.0, Venta: 95.0
# Producto: 32.0, Venta: 44.0
# Producto: 33.0, Venta: 30.0
# Producto: 17.0, Venta: 96.0
# Producto: 20.0, Venta: 97.0
# Producto: 44.0, Venta: 27.0
# Producto: 20.0, Venta: 49.0
# Producto: 20.0, Venta: 57.0
# Producto: 47.0, Venta: 98.0
# Producto: 36.0, Venta: 71.0
# Producto: 15.0, Venta: 58.0
# Producto: 35.0, Venta: 56.0
# Producto: 38.0, Venta: 66.0
# Producto: 45.0, Venta: 97.0
# Producto: 29.0, Venta: 34.0
# Producto: 43.0, Venta: 32.0
# Producto: 31.0, Venta: 14.0
# Producto: 17.0, Venta: 6.0
# Producto: 37.0, Venta: 88.0
# Producto: 18.0, Venta: 78.0
# Producto: 46.0, Venta: 88.0
# Producto: 26.0, Venta: 38.0
# Producto: 16.0, Venta: 98.0
# Producto: 31.0, Venta: 91.0
# Producto: 23.0, Venta: 83.0
# Producto: 30.0, Venta: 11.0
# Producto: 50.0, Venta: 66.0
# Producto: 19.0, Venta: 75.0
# Producto: 23.0, Venta: 53.0
# Producto: 26.0, Venta: 68.0
# Producto: 16.0, Venta: 60.0
# Producto: 39.0, Venta: 40.0
# Producto: 50.0, Venta: 11.0
# Producto: 39.0, Venta: 89.0
# Producto: 31.0, Venta: 13.0
# Producto: 25.0, Venta: 85.0
# Producto: 38.0, Venta: 3.0
# Producto: 21.0, Venta: 71.0
# Producto: 40.0, Venta: 56.0
# Producto: 26.0, Venta: 12.0
# Producto: 32.0, Venta: 18.0
# Producto: 25.0, Venta: 95.0
# Producto: 40.0, Venta: 69.0
# Producto: 22.0, Venta: 93.0
# Producto: 32.0, Venta: 33.0
# Producto: 35.0, Venta: 80.0
# Producto: 43.0, Venta: 49.0
# Producto: 46.0, Venta: 71.0
# Producto: 17.0, Venta: 91.0
# Producto: 25.0, Venta: 3.0
# Producto: 43.0, Venta: 56.0
# Producto: 25.0, Venta: 96.0
# Producto: 36.0, Venta: 96.0
# Producto: 29.0, Venta: 10.0
# Producto: 50.0, Venta: 100.0
# Producto: 15.0, Venta: 16.0
# Producto: 18.0, Venta: 12.0
# Producto: 21.0, Venta: 52.0
# Producto: 15.0, Venta: 42.0
# Producto: 37.0, Venta: 99.0
# Producto: 41.0, Venta: 81.0
# Producto: 17.0, Venta: 44.0
# Producto: 44.0, Venta: 64.0
# Producto: 50.0, Venta: 18.0
# Producto: 30.0, Venta: 0.0
# Producto: 31.0, Venta: 79.0
# Producto: 18.0, Venta: 29.0
# Producto: 22.0, Venta: 91.0
# Producto: 40.0, Venta: 70.0
# Producto: 50.0, Venta: 66.0
# Producto: 24.0, Venta: 51.0
# Producto: 21.0, Venta: 46.0
# Producto: 24.0, Venta: 78.0
# Producto: 44.0, Venta: 95.0
# Producto: 17.0, Venta: 76.0
# Producto: 23.0, Venta: 74.0
# Producto: 36.0, Venta: 59.0
# Producto: 22.0, Venta: 27.0
# Producto: 33.0, Venta: 26.0
# Producto: 45.0, Venta: 17.0
# Producto: 32.0, Venta: 38.0
# Producto: 37.0, Venta: 43.0
# Producto: 38.0, Venta: 9.0
# Producto: 41.0, Venta: 68.0
# Producto: 16.0, Venta: 23.0
# Producto: 26.0, Venta: 24.0
# Producto: 25.0, Venta: 27.0
# Producto: 28.0, Venta: 34.0
# Producto: 28.0, Venta: 33.0
# Producto: 44.0, Venta: 88.0
# Producto: 39.0, Venta: 41.0
# Producto: 32.0, Venta: 41.0
# Producto: 25.0, Venta: 11.0
# Producto: 25.0, Venta: 49.0
# Producto: 21.0, Venta: 19.0
# Producto: 42.0, Venta: 30.0
# Producto: 30.0, Venta: 0.0
# Producto: 22.0, Venta: 72.0
# Producto: 26.0, Venta: 62.0
# Producto: 23.0, Venta: 28.0
# Producto: 29.0, Venta: 98.0
# Producto: 45.0, Venta: 84.0
# Producto: 24.0, Venta: 74.0
# Producto: 27.0, Venta: 26.0
# Producto: 18.0, Venta: 77.0
# Producto: 49.0, Venta: 27.0
# Producto: 47.0, Venta: 50.0
# Producto: 26.0, Venta: 45.0
# Producto: 26.0, Venta: 25.0
# Producto: 39.0, Venta: 10.0
# Producto: 30.0, Venta: 97.0
# Producto: 45.0, Venta: 59.0
# Producto: 50.0, Venta: 31.0
# Producto: 41.0, Venta: 11.0
# Producto: 43.0, Venta: 3.0
# Producto: 22.0, Venta: 99.0
# Producto: 41.0, Venta: 89.0
# Producto: 45.0, Venta: 60.0
# Producto: 41.0, Venta: 46.0
# Producto: 41.0, Venta: 7.0
# Producto: 32.0, Venta: 7.0
# Producto: 16.0, Venta: 4.0
# Producto: 43.0, Venta: 98.0
# Producto: 23.0, Venta: 6.0
# Producto: 16.0, Venta: 97.0
# Producto: 21.0, Venta: 10.0
# Producto: 24.0, Venta: 95.0
# Producto: 35.0, Venta: 43.0
# Producto: 49.0, Venta: 9.0
# Producto: 21.0, Venta: 24.0
# Producto: 37.0, Venta: 46.0
# Producto: 28.0, Venta: 19.0
# Producto: 29.0, Venta: 85.0
# Producto: 40.0, Venta: 98.0
# Producto: 41.0, Venta: 6.0
# Producto: 44.0, Venta: 19.0
# Producto: 38.0, Venta: 89.0
# Producto: 31.0, Venta: 67.0
# Producto: 30.0, Venta: 11.0
# Producto: 28.0, Venta: 57.0
# Producto: 19.0, Venta: 15.0
# Producto: 33.0, Venta: 99.0
# Producto: 26.0, Venta: 27.0
# Producto: 20.0, Venta: 97.0
# Producto: 28.0, Venta: 92.0
# Producto: 41.0, Venta: 89.0
# Producto: 33.0, Venta: 58.0
# Producto: 40.0, Venta: 75.0
# Producto: 42.0, Venta: 11.0
# Producto: 24.0, Venta: 78.0
# Producto: 48.0, Venta: 53.0
# Producto: 21.0, Venta: 22.0
# Producto: 46.0, Venta: 60.0
# Producto: 38.0, Venta: 23.0
# Producto: 35.0, Venta: 24.0
# Producto: 22.0, Venta: 97.0
# Producto: 48.0, Venta: 57.0
# Producto: 38.0, Venta: 35.0
# Producto: 30.0, Venta: 66.0
# Producto: 37.0, Venta: 1.0
# Producto: 19.0, Venta: 40.0
# Producto: 17.0, Venta: 92.0
# Producto: 31.0, Venta: 83.0
# Producto: 45.0, Venta: 1.0
# Producto: 39.0, Venta: 76.0
# Producto: 18.0, Venta: 69.0
# Producto: 18.0, Venta: 45.0
# Producto: 40.0, Venta: 3.0
# Producto: 37.0, Venta: 72.0
# Producto: 18.0, Venta: 77.0
# Producto: 45.0, Venta: 38.0
# Producto: 19.0, Venta: 62.0
# Producto: 33.0, Venta: 4.0
# Producto: 47.0, Venta: 41.0
# Producto: 29.0, Venta: 72.0
# Producto: 50.0, Venta: 56.0
# Producto: 50.0, Venta: 39.0
# Producto: 38.0, Venta: 39.0
# Producto: 15.0, Venta: 81.0
# Producto: 28.0, Venta: 79.0
# Producto: 48.0, Venta: 70.0
# Producto: 45.0, Venta: 40.0
# Producto: 32.0, Venta: 5.0
# Producto: 31.0, Venta: 51.0
# Producto: 24.0, Venta: 72.0
# Producto: 19.0, Venta: 55.0
# Producto: 37.0, Venta: 30.0
# Producto: 17.0, Venta: 3.0
# Producto: 43.0, Venta: 36.0
# Producto: 21.0, Venta: 48.0
# Producto: 16.0, Venta: 32.0
# Producto: 49.0, Venta: 54.0
# Producto: 48.0, Venta: 55.0
# Producto: 18.0, Venta: 52.0
# Producto: 27.0, Venta: 34.0
# Producto: 29.0, Venta: 19.0
# Producto: 47.0, Venta: 95.0
# Producto: 35.0, Venta: 11.0
# Producto: 21.0, Venta: 94.0
# Producto: 48.0, Venta: 31.0
# Producto: 44.0, Venta: 81.0
# Producto: 39.0, Venta: 78.0
# Producto: 36.0, Venta: 15.0
# Producto: 47.0, Venta: 18.0
# Producto: 15.0, Venta: 12.0
# Producto: 48.0, Venta: 94.0
# Producto: 20.0, Venta: 44.0
# Producto: 25.0, Venta: 47.0
# Producto: 36.0, Venta: 39.0
# Producto: 22.0, Venta: 62.0
# Producto: 48.0, Venta: 5.0
# Producto: 35.0, Venta: 51.0
# Producto: 40.0, Venta: 12.0
# Producto: 16.0, Venta: 62.0
# Producto: 23.0, Venta: 13.0
# Producto: 23.0, Venta: 54.0
# Producto: 26.0, Venta: 76.0
# Producto: 44.0, Venta: 54.0
# Producto: 20.0, Venta: 62.0
# Producto: 28.0, Venta: 93.0
# Producto: 49.0, Venta: 12.0
# Producto: 19.0, Venta: 38.0
# Producto: 45.0, Venta: 99.0
# Producto: 47.0, Venta: 27.0
# Producto: 37.0, Venta: 41.0
# Producto: 44.0, Venta: 89.0
# Producto: 36.0, Venta: 67.0
# Producto: 46.0, Venta: 25.0
# Producto: 43.0, Venta: 27.0
# Producto: 47.0, Venta: 36.0
# Producto: 28.0, Venta: 4.0
# Producto: 40.0, Venta: 22.0
# Producto: 41.0, Venta: 66.0
# Producto: 39.0, Venta: 13.0
# Producto: 20.0, Venta: 25.0
# Producto: 36.0, Venta: 49.0
# Producto: 22.0, Venta: 41.0
# Producto: 28.0, Venta: 69.0
# Producto: 45.0, Venta: 99.0
# Producto: 35.0, Venta: 81.0
# Producto: 50.0, Venta: 35.0
# Producto: 41.0, Venta: 86.0
# Producto: 50.0, Venta: 24.0
# Producto: 20.0, Venta: 92.0
# Producto: 32.0, Venta: 96.0
# Producto: 34.0, Venta: 72.0
# Producto: 44.0, Venta: 2.0
# Producto: 23.0, Venta: 84.0
# Producto: 25.0, Venta: 95.0
# Producto: 33.0, Venta: 81.0
# Producto: 30.0, Venta: 7.0
# Producto: 46.0, Venta: 20.0
# Producto: 30.0, Venta: 75.0
# Producto: 37.0, Venta: 25.0
# Producto: 24.0, Venta: 1.0
# Producto: 16.0, Venta: 3.0
# Producto: 47.0, Venta: 29.0
# Producto: 34.0, Venta: 77.0
# Producto: 24.0, Venta: 60.0
# Producto: 36.0, Venta: 99.0
# Producto: 44.0, Venta: 98.0
# Producto: 44.0, Venta: 91.0
# Producto: 20.0, Venta: 19.0
# Producto: 17.0, Venta: 56.0
# Producto: 35.0, Venta: 59.0
# Producto: 34.0, Venta: 18.0
# Producto: 22.0, Venta: 65.0
# Producto: 32.0, Venta: 100.0
# Producto: 23.0, Venta: 46.0
# Producto: 28.0, Venta: 15.0
# Producto: 26.0, Venta: 75.0
# Producto: 47.0, Venta: 59.0
# Producto: 44.0, Venta: 20.0
# Producto: 15.0, Venta: 41.0
# Producto: 32.0, Venta: 40.0
# Producto: 47.0, Venta: 71.0
# Producto: 30.0, Venta: 78.0
# Producto: 30.0, Venta: 61.0
# Producto: 22.0, Venta: 86.0
# Producto: 17.0, Venta: 64.0
# Producto: 27.0, Venta: 30.0
# Producto: 18.0, Venta: 86.0
# Producto: 17.0, Venta: 58.0
# Producto: 43.0, Venta: 76.0
# Producto: 24.0, Venta: 52.0
# Producto: 17.0, Venta: 8.0
# Producto: 43.0, Venta: 73.0
# Producto: 43.0, Venta: 83.0
# Producto: 50.0, Venta: 95.0
# Producto: 37.0, Venta: 7.0
# Producto: 22.0, Venta: 27.0
# Producto: 33.0, Venta: 61.0
# Producto: 48.0, Venta: 39.0
# Producto: 39.0, Venta: 79.0
# Producto: 28.0, Venta: 12.0
# Producto: 21.0, Venta: 6.0
# Producto: 17.0, Venta: 12.0
# Producto: 43.0, Venta: 55.0
# Producto: 21.0, Venta: 48.0
# Producto: 37.0, Venta: 85.0
# Producto: 31.0, Venta: 31.0
# Producto: 36.0, Venta: 1.0
# Producto: 44.0, Venta: 4.0
# Producto: 25.0, Venta: 49.0
# Producto: 18.0, Venta: 22.0
# Producto: 16.0, Venta: 29.0
# Producto: 29.0, Venta: 42.0
# Producto: 25.0, Venta: 100.0
# Producto: 41.0, Venta: 83.0
# Producto: 42.0, Venta: 44.0
# Producto: 39.0, Venta: 29.0
# Producto: 19.0, Venta: 86.0
# Producto: 40.0, Venta: 18.0
# Producto: 21.0, Venta: 46.0
# Producto: 29.0, Venta: 22.0
# Producto: 36.0, Venta: 43.0
# Producto: 48.0, Venta: 15.0
# Producto: 21.0, Venta: 4.0
# Producto: 50.0, Venta: 15.0
# Producto: 19.0, Venta: 57.0
# Producto: 38.0, Venta: 43.0
# Producto: 31.0, Venta: 77.0
# Producto: 27.0, Venta: 66.0
# Producto: 40.0, Venta: 71.0
# Producto: 46.0, Venta: 93.0
# Producto: 35.0, Venta: 75.0
# Producto: 43.0, Venta: 20.0
# Producto: 15.0, Venta: 89.0
# Producto: 47.0, Venta: 84.0
# Producto: 25.0, Venta: 83.0
# Producto: 17.0, Venta: 31.0
# Producto: 41.0, Venta: 77.0
# Producto: 50.0, Venta: 41.0
# Producto: 35.0, Venta: 58.0
# Producto: 27.0, Venta: 35.0
# Producto: 29.0, Venta: 46.0
# Producto: 40.0, Venta: 63.0
# Producto: 40.0, Venta: 85.0
# Producto: 47.0, Venta: 1.0
# Producto: 45.0, Venta: 14.0
# Producto: 28.0, Venta: 99.0
# Producto: 25.0, Venta: 2.0
# Producto: 20.0, Venta: 8.0
# Producto: 49.0, Venta: 51.0
# Producto: 21.0, Venta: 0.0
# Producto: 42.0, Venta: 78.0
# Producto: 47.0, Venta: 79.0
# Producto: 20.0, Venta: 42.0
# Producto: 28.0, Venta: 75.0
# Producto: 37.0, Venta: 23.0
# Producto: 18.0, Venta: 96.0
# Producto: 37.0, Venta: 90.0
# Producto: 37.0, Venta: 60.0
# Producto: 29.0, Venta: 46.0
# Producto: 27.0, Venta: 23.0
# Producto: 46.0, Venta: 73.0
# Producto: 49.0, Venta: 31.0
# Producto: 42.0, Venta: 46.0
# Producto: 44.0, Venta: 55.0
# Producto: 42.0, Venta: 61.0
# Producto: 34.0, Venta: 55.0
# Producto: 24.0, Venta: 83.0
# Producto: 42.0, Venta: 66.0
# Producto: 31.0, Venta: 15.0
# Producto: 40.0, Venta: 90.0
# Producto: 48.0, Venta: 83.0
# Producto: 29.0, Venta: 50.0
# Producto: 29.0, Venta: 100.0
# Producto: 45.0, Venta: 88.0
# Producto: 36.0, Venta: 18.0
# Producto: 15.0, Venta: 1.0
# Producto: 20.0, Venta: 34.0
# Producto: 37.0, Venta: 48.0
# Producto: 26.0, Venta: 26.0
# Producto: 46.0, Venta: 13.0
# Producto: 46.0, Venta: 43.0
# Producto: 29.0, Venta: 48.0
# Producto: 41.0, Venta: 97.0
# Producto: 18.0, Venta: 27.0
# Producto: 35.0, Venta: 64.0
# Producto: 42.0, Venta: 81.0
# Producto: 50.0, Venta: 24.0
# Producto: 23.0, Venta: 19.0
# Producto: 30.0, Venta: 84.0
# Producto: 44.0, Venta: 59.0
# Producto: 31.0, Venta: 38.0
# Producto: 41.0, Venta: 38.0
# Producto: 42.0, Venta: 8.0
# Producto: 17.0, Venta: 55.0
# Producto: 38.0, Venta: 51.0
# Producto: 18.0, Venta: 2.0
# Producto: 20.0, Venta: 45.0
# Producto: 36.0, Venta: 70.0
# Producto: 39.0, Venta: 12.0
# Producto: 32.0, Venta: 48.0
# Producto: 24.0, Venta: 55.0
# Producto: 25.0, Venta: 16.0
# Producto: 26.0, Venta: 46.0
# Producto: 46.0, Venta: 62.0
# Producto: 34.0, Venta: 39.0
# Producto: 31.0, Venta: 95.0
# Producto: 25.0, Venta: 38.0
# Producto: 23.0, Venta: 58.0
# Producto: 29.0, Venta: 88.0
# Producto: 25.0, Venta: 99.0
# Producto: 16.0, Venta: 100.0
# Producto: 35.0, Venta: 60.0
# Producto: 37.0, Venta: 94.0
# Producto: 48.0, Venta: 75.0
# Producto: 46.0, Venta: 10.0
# Producto: 25.0, Venta: 75.0
# Producto: 15.0, Venta: 100.0
# Producto: 42.0, Venta: 45.0
# Producto: 19.0, Venta: 96.0
# Producto: 26.0, Venta: 58.0
# Producto: 42.0, Venta: 69.0
# Producto: 34.0, Venta: 80.0
# Producto: 21.0, Venta: 49.0
# Producto: 27.0, Venta: 16.0
# Producto: 34.0, Venta: 21.0
# Producto: 35.0, Venta: 65.0
# Producto: 37.0, Venta: 7.0
# Producto: 27.0, Venta: 2.0
# Producto: 16.0, Venta: 83.0
# Producto: 47.0, Venta: 18.0
# Producto: 19.0, Venta: 59.0
# Producto: 25.0, Venta: 44.0
# Producto: 47.0, Venta: 64.0
# Producto: 45.0, Venta: 78.0
# Producto: 31.0, Venta: 48.0
# Producto: 28.0, Venta: 65.0
# Producto: 25.0, Venta: 18.0
# Producto: 31.0, Venta: 100.0
# Producto: 41.0, Venta: 79.0
# Producto: 22.0, Venta: 96.0
# Producto: 17.0, Venta: 43.0
# Producto: 22.0, Venta: 83.0
# Producto: 48.0, Venta: 63.0
# Producto: 26.0, Venta: 71.0
# Producto: 22.0, Venta: 11.0
# Producto: 27.0, Venta: 94.0
# Producto: 19.0, Venta: 87.0
# Producto: 16.0, Venta: 16.0
# Producto: 24.0, Venta: 7.0
# Producto: 27.0, Venta: 12.0
# Producto: 47.0, Venta: 99.0
# Producto: 31.0, Venta: 87.0
# Producto: 37.0, Venta: 69.0
# Producto: 40.0, Venta: 69.0
# Producto: 32.0, Venta: 46.0
# Producto: 46.0, Venta: 47.0
# Producto: 45.0, Venta: 55.0
# Producto: 17.0, Venta: 27.0
# Producto: 38.0, Venta: 24.0
# Producto: 49.0, Venta: 91.0
# Producto: 50.0, Venta: 36.0
# Producto: 31.0, Venta: 57.0
# Producto: 47.0, Venta: 76.0
# Producto: 50.0, Venta: 81.0
# Producto: 50.0, Venta: 95.0
# Producto: 35.0, Venta: 15.0
# Producto: 30.0, Venta: 42.0
# Producto: 20.0, Venta: 88.0
# Producto: 28.0, Venta: 43.0
# Producto: 50.0, Venta: 49.0
# Producto: 21.0, Venta: 51.0
# Producto: 39.0, Venta: 86.0
# Producto: 15.0, Venta: 53.0
# Producto: 43.0, Venta: 60.0
# Producto: 40.0, Venta: 28.0
# Producto: 48.0, Venta: 95.0
# Producto: 43.0, Venta: 50.0
# Producto: 18.0, Venta: 47.0
# Producto: 43.0, Venta: 56.0
# Producto: 39.0, Venta: 52.0
# Producto: 39.0, Venta: 58.0
# Producto: 20.0, Venta: 78.0
# Producto: 21.0, Venta: 35.0
# Producto: 27.0, Venta: 5.0
# Producto: 20.0, Venta: 98.0
# Producto: 34.0, Venta: 66.0
# Producto: 38.0, Venta: 41.0
# Producto: 43.0, Venta: 92.0
# Producto: 40.0, Venta: 7.0
# Producto: 38.0, Venta: 70.0
# Producto: 17.0, Venta: 5.0
# Producto: 43.0, Venta: 35.0
# Producto: 20.0, Venta: 7.0
# Producto: 31.0, Venta: 71.0
# Producto: 37.0, Venta: 31.0
# Producto: 40.0, Venta: 9.0
# Producto: 21.0, Venta: 55.0
# Producto: 23.0, Venta: 98.0
# Producto: 38.0, Venta: 97.0
# Producto: 50.0, Venta: 3.0
# Producto: 35.0, Venta: 49.0
# Producto: 43.0, Venta: 26.0
# Producto: 44.0, Venta: 62.0
# Producto: 17.0, Venta: 62.0
# Producto: 23.0, Venta: 61.0
# Producto: 17.0, Venta: 78.0
# Producto: 15.0, Venta: 58.0
# Producto: 27.0, Venta: 89.0
# Producto: 32.0, Venta: 81.0
# Producto: 30.0, Venta: 12.0
# Producto: 32.0, Venta: 99.0
# Producto: 35.0, Venta: 24.0
# Producto: 28.0, Venta: 24.0
# Producto: 28.0, Venta: 18.0
# Producto: 28.0, Venta: 1.0
# Producto: 32.0, Venta: 16.0
# Producto: 19.0, Venta: 2.0
# Producto: 20.0, Venta: 24.0
# Producto: 26.0, Venta: 98.0
# Producto: 33.0, Venta: 65.0
# Producto: 43.0, Venta: 47.0
# Producto: 18.0, Venta: 54.0
# Producto: 33.0, Venta: 96.0
# Producto: 25.0, Venta: 94.0
# Producto: 35.0, Venta: 78.0
# Producto: 16.0, Venta: 83.0
# Producto: 27.0, Venta: 35.0
# Producto: 24.0, Venta: 91.0
# Producto: 23.0, Venta: 65.0
# Producto: 49.0, Venta: 41.0
# Producto: 37.0, Venta: 48.0
# Producto: 21.0, Venta: 34.0
# Producto: 37.0, Venta: 91.0
# Producto: 40.0, Venta: 59.0
# Producto: 21.0, Venta: 41.0
# Producto: 47.0, Venta: 47.0
# Producto: 26.0, Venta: 58.0
# Producto: 33.0, Venta: 55.0
# Producto: 34.0, Venta: 18.0
# Producto: 49.0, Venta: 35.0
# Producto: 39.0, Venta: 60.0
# Producto: 27.0, Venta: 71.0
# Producto: 34.0, Venta: 49.0
# Producto: 28.0, Venta: 68.0
# Producto: 28.0, Venta: 82.0
# Producto: 40.0, Venta: 92.0
# Producto: 28.0, Venta: 68.0
# Producto: 37.0, Venta: 82.0
# Producto: 37.0, Venta: 34.0
# Producto: 23.0, Venta: 2.0
# Producto: 28.0, Venta: 11.0
# Producto: 49.0, Venta: 53.0
# Producto: 19.0, Venta: 52.0
# Producto: 49.0, Venta: 2.0
# Producto: 18.0, Venta: 26.0
# Producto: 18.0, Venta: 92.0
# Producto: 28.0, Venta: 87.0
# Producto: 35.0, Venta: 66.0
# Producto: 16.0, Venta: 64.0
# Producto: 36.0, Venta: 75.0
# Producto: 50.0, Venta: 32.0
# Producto: 39.0, Venta: 88.0
# Producto: 44.0, Venta: 46.0
# Producto: 17.0, Venta: 47.0
# Producto: 24.0, Venta: 67.0
# Producto: 19.0, Venta: 1.0
# Producto: 23.0, Venta: 35.0
# Producto: 33.0, Venta: 77.0
# Producto: 33.0, Venta: 45.0
# Producto: 49.0, Venta: 48.0
# Producto: 45.0, Venta: 90.0
# Producto: 48.0, Venta: 30.0
# Producto: 24.0, Venta: 53.0
# Producto: 37.0, Venta: 82.0
# Producto: 29.0, Venta: 21.0
# Producto: 25.0, Venta: 87.0
# Producto: 18.0, Venta: 100.0
# Producto: 16.0, Venta: 57.0
# Producto: 38.0, Venta: 19.0
# Producto: 42.0, Venta: 95.0
# Producto: 24.0, Venta: 34.0
# Producto: 20.0, Venta: 34.0
# Producto: 45.0, Venta: 95.0
# Producto: 15.0, Venta: 72.0
# Producto: 42.0, Venta: 77.0
# Producto: 49.0, Venta: 35.0
# Producto: 16.0, Venta: 30.0
# Producto: 22.0, Venta: 100.0
# Producto: 46.0, Venta: 12.0
# Producto: 41.0, Venta: 86.0
# Producto: 47.0, Venta: 78.0
# Producto: 40.0, Venta: 60.0
# Producto: 20.0, Venta: 5.0
# Producto: 36.0, Venta: 7.0
# Producto: 47.0, Venta: 73.0
# Producto: 38.0, Venta: 82.0
# Producto: 28.0, Venta: 88.0
# Producto: 20.0, Venta: 35.0
# Producto: 30.0, Venta: 7.0
# Producto: 46.0, Venta: 99.0
# Producto: 25.0, Venta: 7.0
# Producto: 44.0, Venta: 30.0
# Producto: 46.0, Venta: 13.0
# Producto: 32.0, Venta: 81.0
# Producto: 17.0, Venta: 96.0
# Producto: 18.0, Venta: 33.0
# Producto: 23.0, Venta: 8.0
# Producto: 44.0, Venta: 95.0
# Producto: 42.0, Venta: 70.0
# Producto: 17.0, Venta: 55.0
# Producto: 18.0, Venta: 76.0
# Producto: 31.0, Venta: 65.0
# Producto: 26.0, Venta: 96.0
# Producto: 45.0, Venta: 10.0
# Producto: 35.0, Venta: 5.0
# Producto: 18.0, Venta: 45.0
# Producto: 18.0, Venta: 24.0
# Producto: 47.0, Venta: 57.0
# Producto: 44.0, Venta: 79.0
# Producto: 40.0, Venta: 1.0
# Producto: 44.0, Venta: 20.0
# Producto: 30.0, Venta: 21.0
# Producto: 29.0, Venta: 11.0
# Producto: 18.0, Venta: 96.0
# Producto: 29.0, Venta: 75.0
# Producto: 22.0, Venta: 81.0
# Producto: 20.0, Venta: 49.0
# Producto: 36.0, Venta: 38.0
# Producto: 43.0, Venta: 15.0
# Producto: 33.0, Venta: 9.0
# Producto: 16.0, Venta: 23.0
# Producto: 41.0, Venta: 38.0
# Producto: 41.0, Venta: 43.0
# Producto: 42.0, Venta: 92.0
# Producto: 32.0, Venta: 15.0
# Producto: 45.0, Venta: 83.0
# Producto: 17.0, Venta: 60.0
# Producto: 15.0, Venta: 5.0
# Producto: 15.0, Venta: 64.0
# Producto: 31.0, Venta: 66.0
# Producto: 17.0, Venta: 49.0
# Producto: 18.0, Venta: 41.0
# Producto: 19.0, Venta: 37.0
# Producto: 33.0, Venta: 91.0
# Producto: 17.0, Venta: 23.0
# Producto: 23.0, Venta: 66.0
# Producto: 33.0, Venta: 8.0
# Producto: 50.0, Venta: 0.0
# Producto: 18.0, Venta: 73.0
# Producto: 25.0, Venta: 39.0
# Producto: 27.0, Venta: 98.0
# Producto: 45.0, Venta: 51.0
# Producto: 44.0, Venta: 52.0
# Producto: 16.0, Venta: 31.0
# Producto: 38.0, Venta: 75.0
# Producto: 38.0, Venta: 11.0
# Producto: 17.0, Venta: 13.0
# Producto: 32.0, Venta: 38.0
# Producto: 23.0, Venta: 55.0
# Producto: 48.0, Venta: 85.0
# Producto: 16.0, Venta: 91.0
# Producto: 36.0, Venta: 27.0
# Producto: 37.0, Venta: 95.0
# Producto: 20.0, Venta: 62.0
# Producto: 24.0, Venta: 45.0
# Producto: 49.0, Venta: 65.0
# Producto: 46.0, Venta: 3.0
# Producto: 39.0, Venta: 11.0
# Producto: 32.0, Venta: 17.0
# Producto: 49.0, Venta: 63.0
# Producto: 26.0, Venta: 90.0
# Producto: 50.0, Venta: 23.0
# Producto: 33.0, Venta: 16.0
# Producto: 45.0, Venta: 6.0
# Producto: 42.0, Venta: 52.0
# Producto: 15.0, Venta: 67.0
# Producto: 28.0, Venta: 74.0
# Producto: 32.0, Venta: 20.0
# Producto: 27.0, Venta: 2.0
# Producto: 19.0, Venta: 81.0
# Producto: 19.0, Venta: 27.0
# Producto: 47.0, Venta: 8.0
# Producto: 48.0, Venta: 13.0
# Producto: 30.0, Venta: 100.0
# Producto: 19.0, Venta: 84.0
# Producto: 19.0, Venta: 58.0
# Producto: 47.0, Venta: 9.0
# Producto: 33.0, Venta: 87.0
# Producto: 39.0, Venta: 60.0
# Producto: 20.0, Venta: 44.0
# Producto: 49.0, Venta: 11.0
# Producto: 43.0, Venta: 51.0
# Producto: 31.0, Venta: 97.0
# Producto: 42.0, Venta: 41.0
# Producto: 30.0, Venta: 52.0
# Producto: 24.0, Venta: 59.0
# Producto: 21.0, Venta: 18.0
# Producto: 34.0, Venta: 87.0
# Producto: 17.0, Venta: 27.0
# Producto: 20.0, Venta: 53.0
# Producto: 44.0, Venta: 3.0
# Producto: 31.0, Venta: 83.0
# Producto: 32.0, Venta: 0.0
# Producto: 43.0, Venta: 30.0
# Producto: 38.0, Venta: 88.0
# Producto: 36.0, Venta: 60.0
# Producto: 49.0, Venta: 26.0
# Producto: 20.0, Venta: 52.0
# Producto: 23.0, Venta: 77.0
# Producto: 37.0, Venta: 73.0
# Producto: 34.0, Venta: 55.0
# Producto: 23.0, Venta: 97.0
# Producto: 40.0, Venta: 6.0
# Producto: 23.0, Venta: 12.0
# Producto: 47.0, Venta: 58.0
# Producto: 43.0, Venta: 96.0
# Producto: 28.0, Venta: 8.0
# Producto: 30.0, Venta: 75.0
# Producto: 36.0, Venta: 86.0
# Producto: 27.0, Venta: 84.0
# Producto: 39.0, Venta: 83.0
# Producto: 32.0, Venta: 5.0
# Producto: 48.0, Venta: 21.0
# Producto: 16.0, Venta: 43.0
# Producto: 40.0, Venta: 29.0
# Producto: 23.0, Venta: 98.0
# Producto: 40.0, Venta: 35.0
# Producto: 20.0, Venta: 49.0
# Producto: 24.0, Venta: 91.0
# Producto: 46.0, Venta: 49.0
# Producto: 45.0, Venta: 70.0
# Producto: 23.0, Venta: 34.0
# Producto: 18.0, Venta: 89.0
# Producto: 38.0, Venta: 30.0
# Producto: 22.0, Venta: 87.0
# Producto: 17.0, Venta: 15.0
# Producto: 48.0, Venta: 97.0
# Producto: 24.0, Venta: 79.0
# Producto: 17.0, Venta: 96.0
# Producto: 24.0, Venta: 94.0
# Producto: 50.0, Venta: 87.0
# Producto: 46.0, Venta: 39.0
# Producto: 35.0, Venta: 15.0
# Producto: 19.0, Venta: 34.0
# Producto: 17.0, Venta: 40.0
# Producto: 36.0, Venta: 37.0
# Producto: 44.0, Venta: 51.0
# Producto: 39.0, Venta: 25.0
# Producto: 30.0, Venta: 23.0
# Producto: 35.0, Venta: 0.0
# Producto: 36.0, Venta: 63.0
# Producto: 34.0, Venta: 7.0
# Producto: 21.0, Venta: 57.0
# Producto: 39.0, Venta: 97.0
# Producto: 37.0, Venta: 62.0
# Producto: 31.0, Venta: 17.0
# Producto: 45.0, Venta: 79.0
# Producto: 37.0, Venta: 10.0
# Producto: 46.0, Venta: 25.0
# Producto: 35.0, Venta: 61.0
# Producto: 42.0, Venta: 74.0
# Producto: 29.0, Venta: 28.0
# Producto: 40.0, Venta: 23.0
# Producto: 34.0, Venta: 9.0
# Producto: 47.0, Venta: 59.0
# Producto: 23.0, Venta: 79.0
# Producto: 19.0, Venta: 2.0
# Producto: 27.0, Venta: 73.0
# Producto: 18.0, Venta: 77.0
# Producto: 31.0, Venta: 70.0
# Producto: 29.0, Venta: 23.0
# Producto: 23.0, Venta: 54.0
# Producto: 29.0, Venta: 67.0
# Producto: 24.0, Venta: 60.0
# Producto: 33.0, Venta: 45.0
# Producto: 37.0, Venta: 9.0
# Producto: 42.0, Venta: 100.0
# Producto: 34.0, Venta: 92.0
# Producto: 35.0, Venta: 45.0
# Producto: 41.0, Venta: 12.0
# Producto: 35.0, Venta: 13.0
# Producto: 15.0, Venta: 78.0
# Producto: 39.0, Venta: 32.0
# Producto: 24.0, Venta: 61.0
# Producto: 50.0, Venta: 44.0
# Producto: 47.0, Venta: 23.0
# Producto: 34.0, Venta: 43.0
# Producto: 20.0, Venta: 36.0
# Producto: 48.0, Venta: 69.0
# Producto: 28.0, Venta: 70.0
# Producto: 47.0, Venta: 2.0
# Producto: 36.0, Venta: 67.0
# Producto: 31.0, Venta: 46.0
# Producto: 30.0, Venta: 84.0
# Producto: 37.0, Venta: 2.0
# Producto: 19.0, Venta: 43.0
# Producto: 49.0, Venta: 95.0
# Producto: 37.0, Venta: 19.0
# Producto: 42.0, Venta: 83.0
# Producto: 43.0, Venta: 36.0
# Producto: 35.0, Venta: 34.0
# Producto: 30.0, Venta: 12.0
# Producto: 22.0, Venta: 80.0
# Producto: 26.0, Venta: 96.0
# Producto: 24.0, Venta: 22.0
# Producto: 32.0, Venta: 92.0
# Producto: 34.0, Venta: 92.0
# Producto: 21.0, Venta: 35.0
# Producto: 19.0, Venta: 14.0
# Producto: 28.0, Venta: 93.0
# Producto: 33.0, Venta: 48.0
# Producto: 29.0, Venta: 69.0
# Producto: 16.0, Venta: 96.0
# Producto: 32.0, Venta: 43.0
# Producto: 45.0, Venta: 45.0
# Producto: 36.0, Venta: 54.0
# Producto: 21.0, Venta: 83.0
# Producto: 32.0, Venta: 74.0
# Producto: 46.0, Venta: 53.0
# Producto: 21.0, Venta: 95.0
# Producto: 19.0, Venta: 22.0
# Producto: 39.0, Venta: 30.0
# Producto: 22.0, Venta: 42.0
# Producto: 30.0, Venta: 34.0
# Producto: 16.0, Venta: 5.0
# Producto: 20.0, Venta: 70.0
# Producto: 25.0, Venta: 24.0
# Producto: 25.0, Venta: 61.0
# Producto: 24.0, Venta: 42.0
# Producto: 15.0, Venta: 88.0
# Producto: 40.0, Venta: 29.0
# Producto: 23.0, Venta: 96.0
# Producto: 50.0, Venta: 96.0
# Producto: 40.0, Venta: 14.0
# Producto: 31.0, Venta: 28.0
# Producto: 47.0, Venta: 9.0
# Producto: 31.0, Venta: 36.0
# Producto: 24.0, Venta: 99.0
# Producto: 23.0, Venta: 11.0
# Producto: 42.0, Venta: 0.0
# Producto: 38.0, Venta: 46.0
# Producto: 32.0, Venta: 80.0
# Producto: 48.0, Venta: 66.0
# Producto: 46.0, Venta: 55.0
# Producto: 29.0, Venta: 42.0
# Producto: 25.0, Venta: 57.0
# Producto: 37.0, Venta: 58.0
# Producto: 35.0, Venta: 49.0
# Producto: 16.0, Venta: 39.0
# Producto: 32.0, Venta: 75.0
# Producto: 19.0, Venta: 85.0
# Producto: 48.0, Venta: 30.0
# Producto: 20.0, Venta: 32.0
# Producto: 45.0, Venta: 70.0
# Producto: 35.0, Venta: 49.0
# Producto: 37.0, Venta: 41.0
# Producto: 50.0, Venta: 76.0
# Producto: 15.0, Venta: 2.0
# Producto: 34.0, Venta: 85.0
# Producto: 40.0, Venta: 77.0
# Producto: 19.0, Venta: 77.0
# Producto: 17.0, Venta: 79.0
# Producto: 28.0, Venta: 33.0
# Producto: 50.0, Venta: 99.0
# Producto: 49.0, Venta: 72.0
# Producto: 16.0, Venta: 8.0
# Producto: 22.0, Venta: 77.0
# Producto: 17.0, Venta: 59.0
# Producto: 48.0, Venta: 57.0
# Producto: 33.0, Venta: 80.0
# Producto: 21.0, Venta: 33.0
# Producto: 38.0, Venta: 15.0
# Producto: 22.0, Venta: 58.0
# Producto: 39.0, Venta: 95.0
# Producto: 18.0, Venta: 3.0
# Producto: 24.0, Venta: 4.0
# Producto: 45.0, Venta: 100.0
# Producto: 23.0, Venta: 2.0
# Producto: 45.0, Venta: 98.0
# Producto: 27.0, Venta: 54.0
# Producto: 50.0, Venta: 52.0
# Producto: 44.0, Venta: 1.0
# Producto: 34.0, Venta: 90.0
# Producto: 31.0, Venta: 23.0
# Producto: 19.0, Venta: 51.0
# Producto: 36.0, Venta: 21.0
# Producto: 43.0, Venta: 65.0
# Producto: 23.0, Venta: 66.0
# Producto: 35.0, Venta: 86.0
# Producto: 26.0, Venta: 89.0
# Producto: 31.0, Venta: 24.0
# Producto: 41.0, Venta: 16.0
# Producto: 35.0, Venta: 55.0
# Producto: 27.0, Venta: 55.0
# Producto: 28.0, Venta: 64.0
# Producto: 29.0, Venta: 14.0
# Producto: 41.0, Venta: 71.0
# Producto: 33.0, Venta: 58.0
# Producto: 23.0, Venta: 9.0
# Producto: 49.0, Venta: 29.0
# Producto: 48.0, Venta: 64.0
# Producto: 45.0, Venta: 23.0
# Producto: 29.0, Venta: 62.0
# Producto: 28.0, Venta: 65.0
# Producto: 15.0, Venta: 44.0
# Producto: 39.0, Venta: 41.0
# Producto: 46.0, Venta: 72.0
# Producto: 44.0, Venta: 50.0
# Producto: 41.0, Venta: 0.0
# Producto: 47.0, Venta: 24.0
# Producto: 39.0, Venta: 8.0
# Producto: 25.0, Venta: 32.0
# Producto: 48.0, Venta: 86.0
# Producto: 36.0, Venta: 62.0
# Producto: 34.0, Venta: 0.0
# Producto: 39.0, Venta: 45.0
# Producto: 29.0, Venta: 47.0
# Producto: 21.0, Venta: 44.0
# Producto: 23.0, Venta: 48.0
# Producto: 33.0, Venta: 40.0
# Producto: 42.0, Venta: 51.0
# Producto: 17.0, Venta: 71.0
# Producto: 48.0, Venta: 3.0
# Producto: 24.0, Venta: 16.0
# Producto: 48.0, Venta: 53.0
# Producto: 36.0, Venta: 75.0
# Producto: 36.0, Venta: 72.0
# Producto: 30.0, Venta: 2.0
# Producto: 39.0, Venta: 34.0
# Producto: 22.0, Venta: 69.0
# Producto: 16.0, Venta: 96.0
# Producto: 46.0, Venta: 19.0
# Producto: 40.0, Venta: 20.0
# Producto: 32.0, Venta: 38.0
#
# Total de ventas: 277983.0
# Promedio de ventas: 50.73
# Venta máxima: 100.0
# Venta mínima: 0.0
# Desviación estándar de las ventas: 29.52
